# %%
# ->PROGRAMA CON LOS MÉTODOS DE TRAPECIO Y SIMPSON 1/3 ELABORADO POR:
# ->JOSÉ MAURICIO CANUL CHUC
# ->MARCO ANTONIO TUZ PECH
# ->RODRIGO ÁNGEL POOT POOT

import math

# Se define la funcion a inregrar, si se quiere resolver otra, solo se tiene que cambiar la función
def fx(x):
    return math.exp(x)


# Generamos un arreglo con las compression de python
# Este metodo devuelve un arreglo
def arregloEvaluacion(n):
    evaluaciones = [fx(a + i * h) for i in range(n + 1)]
    return evaluaciones


# Método que resuelve la función por el Método del Trapecio
def trapecio(arreglofxi):
    sumapt = sum([arreglofxi[i] for i in range(1, n)])
    resultado = (h / 2) * (arreglofxi[0] + 2 * sumapt + arreglofxi[n])
    print('Integración por el Método de Trapecio', resultado, sep=': ')
    return resultado


# Método que resuelve la función por el Método de Simpson 1/3
def simpson(arreglofxi):
    sumapar = sum([arreglofxi[i] for i in range(1, n) if i % 2 == 0])
    sumapaimpar = sum([arreglofxi[i] for i in range(1, n) if i % 2 != 0])
    resultado = (h / 3) * (arreglofxi[0] + 2 * sumapar + 4 * sumapaimpar + arreglofxi[n])
    print('Integración por el Método de Simpson 1/3', resultado, sep=': ')
    return resultado


opcion=1
while opcion != 4:
    print("\nMenú de Opciones")
    print("1. Método de Trapecio")
    print("2. Método de Simpson 1/3")
    print("3. Resolver con ambos")
    print("4. Salir")
    opcion = int(input("Escriba el número de opción que desea: "))

    if opcion == 1:
        print("\nMétodo de Trapecio")
        n = int(input("Número de Intervalos:"))
        a = float(input("Límite Inferior:"))
        b = float(input("Límite Superior:"))
        h = (b - a) / n
        # Se imprimen los resultados
        print("\nResultado de la Integración:")
        arreglofxi = arregloEvaluacion(n)
        trapecio(arreglofxi)
    elif opcion == 2:
        print("\nMétodo de Simpson 1/3")
        n = int(input("Número de Intervalos:"))
        a = float(input("Límite Inferior:"))
        b = float(input("Límite Superior:"))
        h = (b - a) / n
        # Se imprimen los resultados
        print("\nResultado de la Integración:")
        arreglofxi = arregloEvaluacion(n)
        simpson(arreglofxi)
    elif opcion == 3:
        print("\nResolver por el Método de Trapacio y Simpson 1/3")
        n = int(input("Número de Intervalos:"))
        a = float(input("Límite Inferior:"))
        b = float(input("Límite Superior:"))
        h = (b - a) / n
        # Se imprimen los resultados
        print("\nResultado de las Integraciones:")
        arreglofxi = arregloEvaluacion(n)
        trapecio(arreglofxi)
        simpson(arreglofxi)
    elif opcion == 4:
        opcion == 4
    else:
        print('La opción ingresada no corresponde al menú')
